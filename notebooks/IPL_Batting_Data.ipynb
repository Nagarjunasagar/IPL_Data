# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("season_batting_card.csv")

# %%
df.shape
# Out:
# (919, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 919 entries, 0 to 918
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           919 non-null    float64
#  1   match_id         919 non-null    int64
#  2   match_name       919 non-null    object
#  3   home_team        919 non-null    object
#  4   away_team        919 non-null    object
#  5   venue            919 non-null    object
#  6   city             919 non-null    object
#  7   country          919 non-null    object
#  8   current_innings  919 non-null    object
#  9   innings_id       919 non-null    int64
#  10  name             919 non-null    object
#  11  fullName         919 non-null    object
#  12  runs             919 non-null    int64
#  13  ballsFaced       919 non-null    int64
#  14  minutes          919 non-null    object
#  15  fours            919 non-null    int64
#  16  sixes            919 non-null    int64
# ...

# %%
df.corr()
# Out:
#              season  match_id  innings_id      runs  ballsFaced     fours  \
# season          NaN       NaN         NaN       NaN         NaN       NaN
# match_id        NaN  1.000000   -0.002587 -0.036003    0.004110 -0.066425
# innings_id      NaN -0.002587    1.000000  0.036305    0.028889  0.049325
# runs            NaN -0.036003    0.036305  1.000000    0.934565  0.880518
# ballsFaced      NaN  0.004110    0.028889  0.934565    1.000000  0.796551
# fours           NaN -0.066425    0.049325  0.880518    0.796551  1.000000
# sixes           NaN -0.062878    0.020801  0.793107    0.637772  0.530644
# captain         NaN  0.008734    0.020768  0.152058    0.186271  0.136440
# isNotOut        NaN  0.016726    0.066403  0.036995   -0.040439 -0.012306
# runningOver     NaN -0.026881   -0.087194  0.170310    0.150956  0.050087
# link            NaN       NaN         NaN       NaN         NaN       NaN
#
#                 sixes   captain  isNotOut  runningOver  link
# ...

# %%
df.sample(n=10)
# Out:
#      season  match_id match_name home_team away_team  \
# 822  2021.0   1254063  SRH v RCB       SRH       RCB
# 617  2021.0   1254076  CSK v RCB       CSK       RCB
# 327  2021.0   1254108   RCB v MI       RCB        MI
# 285  2021.0   1254092   KKR v DC       KKR        DC
# 380  2021.0   1254097    DC v RR        DC        RR
# 912  2021.0   1254058   MI v RCB        MI       RCB
# 343  2021.0   1254098  CSK v KKR       CSK       KKR
# 381  2021.0   1254113  RCB v CSK       RCB       CSK
# 667  2021.0   1254072  KKR v CSK       KKR       CSK
# 129  2021.0   1254093    RR v MI        RR        MI
#
#                                         venue       city  \
# 822  MA Chidambaram Stadium, Chepauk, Chennai    Chennai
# 617                  Wankhede Stadium, Mumbai     Mumbai
# 327       Dubai International Cricket Stadium      Dubai
# 285                   Sharjah Cricket Stadium    Sharjah
# 380           Sheikh Zayed Stadium, Abu Dhabi  Abu Dhabi
# ...

# %%
df.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team', 'venue',
#        'city', 'country', 'current_innings', 'innings_id', 'name', 'fullName',
#        'runs', 'ballsFaced', 'minutes', 'fours', 'sixes', 'strikeRate',
#        'captain', 'isNotOut', 'runningScore', 'runningOver', 'shortText',
#        'commentary', 'link'],
#       dtype='object')

# %%
print(df['home_team'].nunique(),df['away_team'].nunique(),df['venue'].nunique(), df['country'].nunique(), df['match_name'].nunique())
# Out:
# 8 8 7 2 56

# %%
df.nlargest(10, 'runs')
# Out:
#      season  match_id  match_name home_team away_team  \
# 484  2021.0   1254085    RR v SRH        RR       SRH
# 866  2021.0   1254061   RR v PBKS        RR      PBKS
# 191  2021.0   1254089    RR v CSK        RR       CSK
# 666  2021.0   1254073    RCB v RR       RCB        RR
# 472  2021.0   1254086   PBKS v DC      PBKS        DC
# 105  2021.0   1254094  CSK v PBKS       CSK      PBKS
# 668  2021.0   1254072   KKR v CSK       KKR       CSK
# 743  2021.0   1254068   DC v PBKS        DC      PBKS
# 513  2021.0   1254083  PBKS v RCB      PBKS       RCB
# 857  2021.0   1254061   RR v PBKS        RR      PBKS
#
#                                         venue       city  \
# 484               Arun Jaitley Stadium, Delhi      Delhi
# 866                  Wankhede Stadium, Mumbai     Mumbai
# 191           Sheikh Zayed Stadium, Abu Dhabi  Abu Dhabi
# 666                  Wankhede Stadium, Mumbai     Mumbai
# 472  Narendra Modi Stadium, Motera, Ahmedabad  Ahmedabad
# ...

# %%
df.isnull().sum()
# Out:
# season               0
# match_id             0
# match_name           0
# home_team            0
# away_team            0
# venue                0
# city                 0
# country              0
# current_innings      0
# innings_id           0
# name                 0
# fullName             0
# runs                 0
# ballsFaced           0
# minutes              0
# fours                0
# sixes                0
# strikeRate           0
# captain              0
# isNotOut             0
# runningScore         0
# runningOver        214
# shortText            0
# commentary         214
# link               919
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 919 entries, 0 to 918
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           919 non-null    float64
#  1   match_id         919 non-null    int64
#  2   match_name       919 non-null    object
#  3   home_team        919 non-null    object
#  4   away_team        919 non-null    object
#  5   venue            919 non-null    object
#  6   city             919 non-null    object
#  7   country          919 non-null    object
#  8   current_innings  919 non-null    object
#  9   innings_id       919 non-null    int64
#  10  name             919 non-null    object
#  11  fullName         919 non-null    object
#  12  runs             919 non-null    int64
#  13  ballsFaced       919 non-null    int64
#  14  minutes          919 non-null    object
#  15  fours            919 non-null    int64
#  16  sixes            919 non-null    int64
# ...

# %%
data = df[['season', 'match_id', 'match_name', 'home_team', 'away_team', 'venue',
       'city', 'country', 'current_innings', 'innings_id', 'name', 'fullName',
       'runs', 'ballsFaced', 'minutes', 'fours', 'sixes', 'strikeRate',
       'captain', 'isNotOut', 'runningScore', 'shortText',
       ]]
