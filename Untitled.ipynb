# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("season_batting_card.csv")

# %%
df.head(50)
# Out:
#     season  match_id match_name home_team away_team  \
# 0   2021.0   1254116   DC v KKR        DC       KKR
# 1   2021.0   1254116   DC v KKR        DC       KKR
# 2   2021.0   1254116   DC v KKR        DC       KKR
# 3   2021.0   1254116   DC v KKR        DC       KKR
# 4   2021.0   1254116   DC v KKR        DC       KKR
# 5   2021.0   1254116   DC v KKR        DC       KKR
# 6   2021.0   1254116   DC v KKR        DC       KKR
# 7   2021.0   1254116   DC v KKR        DC       KKR
# 8   2021.0   1254116   DC v KKR        DC       KKR
# 9   2021.0   1254116   DC v KKR        DC       KKR
# 10  2021.0   1254116   DC v KKR        DC       KKR
# 11  2021.0   1254116   DC v KKR        DC       KKR
# 12  2021.0   1254116   DC v KKR        DC       KKR
# 13  2021.0   1254116   DC v KKR        DC       KKR
# 14  2021.0   1254116   DC v KKR        DC       KKR
# 15  2021.0   1254116   DC v KKR        DC       KKR
# 16  2021.0   1254115  RCB v KKR       RCB       KKR
# ...

# %%
df.shape
# Out:
# (919, 25)

# %%
df["match_name"].unique()
# Out:
# array(['DC v KKR', 'RCB v KKR', 'DC v CSK', 'RCB v DC', 'SRH v MI',
#        'KKR v RR', 'CSK v PBKS', 'RCB v SRH', 'RR v MI', 'KKR v SRH',
#        'RCB v PBKS', 'RR v CSK', 'MI v DC', 'KKR v PBKS', 'SRH v CSK',
#        'RR v RCB', 'MI v PBKS', 'KKR v DC', 'SRH v RR', 'RCB v MI',
#        'CSK v KKR', 'SRH v PBKS', 'DC v RR', 'RCB v CSK', 'MI v KKR',
#        'DC v SRH', 'PBKS v RR', 'KKR v RCB', 'CSK v MI', 'PBKS v DC',
#        'RR v SRH', 'MI v CSK', 'PBKS v RCB', 'MI v RR', 'CSK v SRH',
#        'DC v RCB', 'PBKS v KKR', 'SRH v DC', 'CSK v RCB', 'RR v KKR',
#        'PBKS v MI', 'RCB v RR', 'KKR v CSK', 'PBKS v SRH', 'DC v MI',
#        'CSK v RR', 'DC v PBKS', 'MI v SRH', 'PBKS v CSK', 'RR v DC',
#        'SRH v RCB', 'KKR v MI', 'RR v PBKS', 'SRH v KKR', 'CSK v DC',
#        'MI v RCB'], dtype=object)

# %%
df.isnull().sum()
# Out:
# season               0
# match_id             0
# match_name           0
# home_team            0
# away_team            0
# venue                0
# city                 0
# country              0
# current_innings      0
# innings_id           0
# name                 0
# fullName             0
# runs                 0
# ballsFaced           0
# minutes              0
# fours                0
# sixes                0
# strikeRate           0
# captain              0
# isNotOut             0
# runningScore         0
# runningOver        214
# shortText            0
# commentary         214
# link               919
# dtype: int64

# %%
df.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team', 'venue',
#        'city', 'country', 'current_innings', 'innings_id', 'name', 'fullName',
#        'runs', 'ballsFaced', 'minutes', 'fours', 'sixes', 'strikeRate',
#        'captain', 'isNotOut', 'runningScore', 'runningOver', 'shortText',
#        'commentary', 'link'],
#       dtype='object')

# %%
final_dataset = df[['season', 'match_id', 'home_team', 'away_team', 'venue',
       'city', 'country', 'fullName',
       'runs', 'ballsFaced', 'minutes', 'fours', 'sixes', 'strikeRate',
       'runningScore', 'runningOver', 
      ]]

# %%
final_dataset.head()
# Out:
#    season  match_id home_team away_team                    venue     city  \
# 0  2021.0   1254116        DC       KKR  Sharjah Cricket Stadium  Sharjah
# 1  2021.0   1254116        DC       KKR  Sharjah Cricket Stadium  Sharjah
# 2  2021.0   1254116        DC       KKR  Sharjah Cricket Stadium  Sharjah
# 3  2021.0   1254116        DC       KKR  Sharjah Cricket Stadium  Sharjah
# 4  2021.0   1254116        DC       KKR  Sharjah Cricket Stadium  Sharjah
#
#                 country        fullName  runs  ballsFaced minutes  fours  \
# 0  United Arab Emirates    Prithvi Shaw    18          12      17      2
# 1  United Arab Emirates  Shikhar Dhawan    36          39      65      1
# 2  United Arab Emirates  Marcus Stoinis    18          23      36      1
# 3  United Arab Emirates    Shreyas Iyer    30          27      48      1
# 4  United Arab Emirates    Rishabh Pant     6           6       6      1
#
#    sixes strikeRate                runningScore  runningOver
# ...

# %%
df.head()
# Out:
#    season  match_id match_name home_team away_team                    venue  \
# 0  2021.0   1254116   DC v KKR        DC       KKR  Sharjah Cricket Stadium
# 1  2021.0   1254116   DC v KKR        DC       KKR  Sharjah Cricket Stadium
# 2  2021.0   1254116   DC v KKR        DC       KKR  Sharjah Cricket Stadium
# 3  2021.0   1254116   DC v KKR        DC       KKR  Sharjah Cricket Stadium
# 4  2021.0   1254116   DC v KKR        DC       KKR  Sharjah Cricket Stadium
#
#       city               country current_innings  innings_id  ... fours sixes  \
# 0  Sharjah  United Arab Emirates              DC           1  ...     2     1
# 1  Sharjah  United Arab Emirates              DC           1  ...     1     2
# 2  Sharjah  United Arab Emirates              DC           1  ...     1     0
# 3  Sharjah  United Arab Emirates              DC           1  ...     1     1
# 4  Sharjah  United Arab Emirates              DC           1  ...     1     0
#
# ...
